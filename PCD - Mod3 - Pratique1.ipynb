# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SINASC_RO_2019.csv')
df[['APGAR1', 'APGAR5', 'SEXO', 'GESTACAO', 'ESTCIVMAE']]
# Out:
#        APGAR1  APGAR5       SEXO         GESTACAO  ESTCIVMAE
# 0         9.0    10.0  Masculino  37 a 41 semanas        5.0
# 1         8.0     9.0   Feminino  37 a 41 semanas        2.0
# 2         8.0    10.0   Feminino  37 a 41 semanas        9.0
# 3         9.0    10.0   Feminino  37 a 41 semanas        5.0
# 4         8.0    10.0   Feminino  37 a 41 semanas        2.0
# ...       ...     ...        ...              ...        ...
# 27023     8.0     9.0  Masculino  32 a 36 semanas        2.0
# 27024     8.0     9.0  Masculino  37 a 41 semanas        1.0
# 27025     9.0    10.0  Masculino  37 a 41 semanas        2.0
# 27026     8.0     9.0  Masculino  32 a 36 semanas        2.0
# 27027     7.0     8.0  Masculino  37 a 41 semanas        5.0
#
# [27028 rows x 5 columns]

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
plt.close('all')
plt.rc('figure', figsize=(10,10))
fig, axes = plt.subplots(3,2)

sns.countplot(ax = axes[0,0], x='APGAR1', data=df)
sns.countplot(ax = axes[0,1], x='APGAR5', data=df)
sns.countplot(ax = axes[1,0], x='SEXO', data=df)

ax_gestacao = sns.countplot(ax = axes[1,1], x='GESTACAO', data=df)
ax_gestacao.set_xticklabels(ax_gestacao.get_xticklabels(), rotation = 45, ha = 'right')


sns.countplot(ax = axes[2,0], x='ESTCIVMAE', data=df)

plt.subplots_adjust(hspace=0.8)
plt.show()

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
sns.barplot(x = 'APGAR5', y = 'CONSULTAS', data = df)
# Out:
# <Axes: xlabel='APGAR5', ylabel='CONSULTAS'>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize=(10,10))
fig, axes = plt.subplots(2,2)

sns.countplot(ax = axes[0,0], x='SEXO', data=df)

ax_gestacao = sns.countplot(ax = axes[0,1], x='GESTACAO', data=df)
ax_gestacao.set_xticklabels(ax_gestacao.get_xticklabels(), rotation = 45, ha = 'right')


sns.countplot(ax = axes[1,0], x='ESTCIVMAE', data=df)
sns.countplot(ax = axes[1,1], x='CONSULTAS', data=df)

plt.subplots_adjust(hspace=0.8)
plt.show()
