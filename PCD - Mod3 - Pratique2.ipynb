# %% [markdown]
# # Módulo 06 Tarefa 2

# %% [markdown]
# Vamos praticar agora análise descritiva de variáveis contínuas na base do DataSUS

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SINASC_RO_2019.csv')

df[['IDADEMAE', 'PESO']]
# Out:
#        IDADEMAE  PESO
# 0            19  3685
# 1            29  3055
# 2            37  3460
# 3            30  2982
# 4            30  3310
# ...         ...   ...
# 27023        32  2110
# 27024        19  3310
# 27025        24  3065
# 27026        21  2352
# 27027        18  4240
#
# [27028 rows x 2 columns]

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(data=df['IDADEMAE'])
# Out:
# <Axes: >

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(data=df['PESO'])
# Out:
# <Axes: >

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.displot(data = df['IDADEMAE'], alpha = .25, bins = 20, element = 'step', kde = True)
# Out:
# C:\Users\danil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.displot(data = df['PESO'], alpha = .25, bins = 20, element = 'step', kde = True)
# Out:
# C:\Users\danil\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
